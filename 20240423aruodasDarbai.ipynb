# %%
#standartiniai moduliai
import numpy as np
import numpy.polynomial.polynomial as poly
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from datetime import datetime
from dateutil import parser
# import mysql.connector as cnt
#import panel as pn
#pn.extension()
import seaborn as sns
import os, sys
print(os.getcwd())
fontsize=16 #for all entries
titlesize=24
labelsize=16
fwidth=6
fheight=4
# Out:
# c:\Users\rezav\OneDrive\Stalinis kompiuteris\Duomenų mokslas\JupyterNotebooksR

# %%
import time
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup

opcijos = Options()
opcijos.add_argument('--incognito')

driver = webdriver.Firefox(options=opcijos)
url = 'https://autoplius.lt/skelbimai/naudoti-automobiliai?page_nr=2'
driver.get(url)
time.sleep(10)
source = driver.page_source
bs = BeautifulSoup(source, 'html.parser')
ResultsSet = bs.find_all('div', {'class':'announcement-body-heading'})

automobiliai = []
for item in ResultsSet:
    automobilis = item.find('div', {'class': 'announcement-title'})
    automobiliai.append(automobilis.text.strip())

automobilis = ResultsSet.find('div', {'class': 'announcement-title'})
#             kainaFloat = float(kainaRaw.text.strip().replace(' ', '').replace('€', ''))

pagaminimo_metai = []

announcement-parameters


print(automobiliai)
print('--------------NEW--------------------')
driver.close()
# Out:
# ['Mercedes-Benz CLS350', 'Volkswagen Golf', 'BMW X5', 'BMW 630 Gran Turismo', 'Mitsubishi Carisma', 'Toyota Avensis', 'Volkswagen Transporter', 'Hyundai i20', 'Ford Tourneo Connect', 'Toyota Prius', 'Toyota RAV4', 'Toyota Avensis', 'Volkswagen CC', 'BMW X5', 'BMW 535', 'Seat Leon', 'Volkswagen Golf', 'BMW 320', 'Toyota Highlander', 'Audi A6']
# --------------NEW--------------------

# %%
automobilis = ResultsSet.find('div', {'class': 'announcement-title'})
print(automobilis)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 automobilis = ResultsSet.find('div', {'class': 'announcement-title'})
#       2 print(automobilis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import time
import selenium
# import undetected_chromedriver as uc
from selenium import webdriver
# from selenium.webdriver.chrome.options import Options
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup

opcijos = Options()
opcijos.add_argument('--incognito')
# opcijos.add_argument('--headless')

# driver = uc.Chrome(options=opcijos)
driver = webdriver.Firefox(options=opcijos)

# jūsų atrankoje, kiek automobilių buvo au atomatu, mech, kokios jų buvo vidutinės kainos?
#advanced: su pie plot atvaizduokite gamintojų užimamą rinkos dalį (5 didžiausi + visi kiti)

pavadinimai = []
pagaminimo_metai = []
pavaru_dezes = []
kuro_tipas = []
miestai = []
ridos = []

for puslapis in range(1,2):
    url = f'https://autoplius.lt/skelbimai/naudoti-automobiliai?page_nr={puslapis}'
    driver.get(url)
    time.sleep(10)
    source = driver.page_source
    bs = BeautifulSoup(source, 'html.parser')
    SkelbimuSarasas = bs.find_all('div', {'class':'announcement-body'})

    for skelbimas in SkelbimuSarasas:
        try:            
            pavadinimas = skelbimas.find('div', {'class': 'announcement-title'}).text.strip()
            pavadinimai.append(pavadinimas)

            pagaminimo_data = skelbimas.find('div', {'class': 'announcement-parameters'}).text.strip()[:4]
            pagaminimo_metai.append(pagaminimo_data)

            pavaru_deze = skelbimas.find('div', {'class':'announcement-parameters-block'}).find('div', {'class': 'announcement-parameters'}).text.strip().replace('\n', ';').replace('   ', '').split(';')[1]
            pavaru_dezes.append(pavaru_deze)

            kuro_tip = skelbimas.find('div', {'class':'announcement-parameters-block'}).find('div', {'class': 'announcement-parameters'}).text.strip().replace('\n', ';').replace('   ', '').split(';')[0]
            kuro_tipas.append(kuro_tip)

            miestas = skelbimas.find('div', {'class':'announcement-parameters-block'}).find('div', {'class': 'announcement-parameters'}).text.strip().replace('\n', ';').replace('   ', '').split(';')[-1]
            miestai.append(miestas)

            kint = skelbimas.find('div', {'class':'announcement-parameters-block'}).find('div', {'class': 'announcement-parameters'}).text.strip().replace('\n', ';').replace('   ', '')

            for el in kint.split(';'):
                if 'km' in el:
                    kilometrazas = el.replace('km', '').replace(' ', '')
                    ridos.append(int(kilometrazas))
                    break 
            if not ridos:  
                ridos.append('nenurodyta')









            bendras = skelbimas.find('div', {'class':'announcement-parameters-block'}).find('div', {'class': 'announcement-parameters'}).text.strip().replace('\n', ' ').replace('   ', '')
           
            

        


            print(pavadinimas)
            print(pagaminimo_data)
            print(pavaru_deze)
            print(kuro_tip)
            
            print(bendras)
            print(kint)
            print('-------------------kitas------------------------')
        

#             t
        except Exception as klaida:
            print(klaida)
#     # time.sleep(np.random.randint(10,100))
#     time.sleep(5)
driver.close()
print(len(miestas))
print(len(ridos))

# dfVisiSkelbimai = pd.DataFrame(data={'Adresas':Adresas, 'Kaina':Kaina, 'Kaina_uz_m2':Kaina_uz_m2, 'Plotas':Plotas, 'Kambariu_skaicius':Kambariu_skaicius})

# dfVisiSkelbimai.to_csv('20240423AruodasVisiSkelbimai.csv', sep=';')
# Out:
# Mercedes-Benz C220
# 2018
# Automatinė
# Dyzelinas
# Dyzelinas  Automatinė 2.1 l.,125  kW  203 000 km Kaunas
# Dyzelinas ;Automatinė;;  2.1 l.,125  kW ;203 000 km;Kaunas
# -------------------kitas------------------------
# BMW 320
# 2021
# Automatinė
# Dyzelinas / elektra
# Dyzelinas / elektra  Automatinė 2.0 l.,140  kW  70 000 km Kaunas
# Dyzelinas / elektra ;Automatinė;;  2.0 l.,140  kW ;70 000 km;Kaunas
# -------------------kitas------------------------
# Mini Countryman S
# 2019
# Automatinė
# Benzinas
# Benzinas  Automatinė 24 579 km Vilnius
# Benzinas ;Automatinė;24 579 km;Vilnius
# -------------------kitas------------------------
# BMW 530
# 2022
# Automatinė
# Benzinas
# Benzinas  Automatinė 2.0 l.,185  kW  24 500 km Kaunas
# Benzinas ;Automatinė;;  2.0 l.,185  kW ;24 500 km;Kaunas
# -------------------kitas------------------------
# Jeep Grand Cherokee
# 2011
# Automatinė
# Dyzelinas
# Dyzelinas  Automatinė 3.0 l.,177  kW  370 000 km Trakai
# ...
